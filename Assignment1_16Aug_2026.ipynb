# %% [markdown]
#  **Assignment No.1 date 16-Aug-2026**

# %% [markdown]
# 1. Create variables for a student's name, age, city, and student status. Print all the information in a properly formatted output.

# %%
StudentName="Habib"
Age=40
City="Karachi"
Status="Active"
print("Student_Information")
print("===================")
print( f"Name: {StudentName}")
print( f"Age: {Age}")
print( f"City: {City}")
print( f"Status: {Status}")
# Out:
# Student_Information
# ...
# Name: Habib
# Age: 40
# City: Karachi
# Status: Active

# %% [markdown]
# No.2. Create variables containing a string, integer, float, and boolean. Print the value and data type of each variable using type().

# %%
Name="Habib"
Age=45
Weight=90.5
IsStudent=True
print("Name, Type    :",type(Name))
print("Age, Type     :",type(Age))
print("Weight, Type  :",type(Weight))
print("IsStudent,Type:",type(IsStudent))
# Out:
# Name, Type    : <class 'str'>
# Age, Type     : <class 'int'>
# Weight, Type  : <class 'float'>
# IsStudent,Type: <class 'bool'>

# %% [markdown]
# 3. Create two number variables and calculate their:
# • Addition
# • Subtraction
# • Multiplication
# • Division
# • Modulus
# • Power

# %%
a=17
b=2
print("Fist Number:",a)
print("Second Number:",b)
print("================")
print('Sum:',a+b)
print('Sub:',a-b)
print('Mul:',a*b)
print('Div:',a/b)
print('Mod:',a%b)
print('Pow:',a**b)
# Out:
# Fist Number: 17
# Second Number: 2
# ...
# Sum: 19
# Sub: 15
# Mul: 34
# Div: 8.5
# Mod: 1
# Pow: 289

# %% [markdown]
# 4. Store the marks of three subjects in separate variables. Calculate and print the total marks and average marks.

# %%
MarksPhysics=85
MarksMaths=96
MarksEng=72
print("Marks Sheet")
print("Name", StudentName)
print("Physics:", MarksPhysics)
print("Maths:", MarksMaths)
print("English:", MarksEng)
print("Total Marks:", (MarksPhysics+MarksMaths+ MarksEng))
print("Average Marks:", (MarksPhysics+ MarksMaths+ MarksEng)/3)
# Out:
# Marks Sheet
# Name Habib
# Physics: 85
# Maths: 96
# English: 72
# Total Marks: 253
# Average Marks: 84.33333333333333

# %% [markdown]
# 5. Create variables for the product price and quantity. Calculate and print the total bill.

# %%
ShirtPrice=300
ShirtQty=5
TshirtPrice=200
TshirtQty=4
print("Qty Description Rate    Amount")
print("-----------------------------")
print( ShirtQty,"  Shirts     @", ShirtPrice,"  =",ShirtPrice*ShirtQty)
print(TshirtQty,"  TShirts    @", TshirtPrice, "  =",TshirtPrice*TshirtQty)
print("-----------------------------")
print("                  Total:",(ShirtPrice*ShirtQty)+(TshirtPrice*TshirtQty))
#
# Out:
# Qty Description Rate    Amount
# -----------------------------
# 5   Shirts     @ 300   = 1500
# 4   TShirts    @ 200   = 800
# -----------------------------
#                   Total: 2300

# %% [markdown]
# 6. Create variables for the length and width of a rectangle. Calculate and print its area and perimeter.

# %%
Length = 15
Width = 10
area = Length * Width
perimeter = 2 * (Length + Width)
print("Length:",Length)
print("Width:",Width)
print("Area of Rectangle:",area)
print("Perimeter of Rectangle:",perimeter)
# Out:
# Length: 15
# Width: 10
# Area of Rectangle: 150
# Perimeter of Rectangle: 50

# %% [markdown]
# 7. Store 250 minutes in a variable. Calculate and print the number of hours and remaining minutes.

# %%
TimeInMinutes = 250
Hours = TimeInMinutes // 60
RemainingMinutes = TimeInMinutes % 60
print("Time in Minutes:", TimeInMinutes)
print("Hours:", Hours)
print("Remaining Minutes:", RemainingMinutes)
# Out:
# Time in Minutes: 250
# Hours: 4
# Remaining Minutes: 10

# %% [markdown]
# 8. Create variables for marks and attendance. A student is eligible if: • Marks are greater than or equal to 50  • Attendance is greater than or equal to 75  Use logical operators to calculate and print whether the student is eligible.

# %%
Marks = 49
Attendance = 80
print("Marks:", Marks)
print("Attendance:", Attendance)
Eligible = (Marks >= 50) and (Attendance >=75)
print("Eligibility:", Eligible)
# Out:
# Marks: 49
# Attendance: 80
# Eligibility: False

# %% [markdown]
# Create two Boolean variables: a = True b = False Print the results of: • a and b • a or b • not a • not b

# %%
a= True
b= False
print("a:",a)
print("b:",b)
print("result of 'a and b':", a and b)
print("result of 'a or b':", a or b)
print("result of 'not a':", not a)
print("result of 'not b':", not b)
# Out:
# a: True
# b: False
# result of 'a and b': False
# result of 'a or b': True
# result of 'not a': False
# result of 'not b': True

# %% [markdown]
# 10. Create variables for: • Student name  • Age  • Marks of 3 subjects  • Attendance  Then: 1. Print the student's information.  2. Calculate and print the total marks.  3. Calculate and print the average marks.  4. Use logical operators to calculate and print whether the student is eligible:  o Average marks >= 50  o Attendance >= 75  Restriction: Do not use if, else, or elif

# %%
StudentName="Habib"
MarksPhysics=49
MarksMaths=98
MarksEng=72
Attendance = 80
Marks=(MarksPhysics+MarksMaths+ MarksEng)
Aveg=(MarksPhysics+MarksMaths+ MarksEng)/3
print("Student Information")
print("===================")
print( f"Name: {StudentName}")
print( f"Physics:", MarksPhysics)
print( f"Maths:", MarksMaths)
print( f"English:", MarksEng)
print("-------------------")
print("Total Marks:", Marks)
print("Average Marks:", Aveg)
print("Attendance:", Attendance)
Eligible = (Aveg >= 50) and (Attendance >=75)
print("Eligibility:", Eligible)
# Out:
# Student Information
# ...
# Name: Habib
# Physics: 49
# Maths: 98
# English: 72
# -------------------
# Total Marks: 219
# Average Marks: 73.0
# Attendance: 80
# Eligibility: True
